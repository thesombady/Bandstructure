# %%
# %matplotlib notebook
# %run 2D_bandstructure_User_interface.ipynb
display(FirstBox)
fig
# Out:
# Wall time: 578 ms
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="960">
# ...
# <img src="data:image/png;base64,..." width="960">
