# %% [markdown]
# ### Run the cell below by pressing twice *ctrl + enter* and enjoy the game:
# remember to read the lab manual (and also *Readme.md*) and to make sure *ipywidgets* is installed
#
# The standard deviation $\sigma$ of the potential is kept constant = 0.5 Å

# %%
# %run User_interface.ipynb
display(FirstBox, SecondBox)
fig
# Out:
# Wall time: 69 ms
# HBox(children=(Label(value='Lattice constant (Å)'), FloatSlider(value=3.0, continuous_update=False, max=10.0, …
# HBox(children=(Label(value='N of K vectors'), IntSlider(value=6, continuous_update=False, max=20, min=1), Labe…
# <img src="data:image/png;base64,..." width="950">
